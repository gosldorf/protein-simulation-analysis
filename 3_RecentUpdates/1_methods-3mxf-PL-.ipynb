# %% [markdown]
# ## Methods notebook
#
# point of this notebook is to take the ideas from the working notebook to make some methods

# %%
#############################Import Block#############################
from ProteinAnalysis import proteinAnalysis
from pathlib import Path
import glob
#############################Import Block#############################

# %% [markdown]
# ## Test method definitions before making a .py that would be importable

# %%
current_dir = Path().absolute()
data_dir = Path('/Users/stevenramsey/BromoDomains/3mxf-500ns-PL')
trajectories = glob.glob(str(data_dir / '*.dcd'))
print(trajectories)
topologies = glob.glob(str(data_dir / '*.prmtop'))
print(topologies)
pdbfiles = glob.glob(str(data_dir / '*.pdb'))
print(pdbfiles)
sdffiles = glob.glob(str(data_dir / '*.sdf'))
print(sdffiles)
out_dir = current_dir / '3mxf-PL'
out_dir.mkdir(parents=True, exist_ok=True)
# Out:
# ['/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/prod_aligned.dcd', '/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/prod_stripped.dcd']
# ['/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/complex_ion.prmtop', '/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/protein_ion.prmtop', '/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/complex_stripped.prmtop', '/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/ligand_wat.prmtop', '/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/complex_wat.prmtop', '/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/protein_wat.prmtop', '/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/ligand_vac.prmtop']
# ['/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/last_frame.pdb', '/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/minimized.pdb', '/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/equilibrated.pdb', '/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/ligand.pdb', '/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/3mxf_prepared.pdb', '/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/heated.pdb', '/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/topology.pdb', '/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/sqm.pdb', '/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/ligand_prepared.pdb']
# ['/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/ligand.sdf']

# %%
trajectories[1]
# Out:
# '/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/prod_stripped.dcd'

# %%
topologies[2]
# Out:
# '/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/complex_stripped.prmtop'

# %%
pdbfiles[0]
# Out:
# '/Users/stevenramsey/BromoDomains/3mxf-500ns-PL/last_frame.pdb'

# %%
pA = proteinAnalysis(pdbfiles[0], out_dir, timestep=5)
pA.loadTrajectory(trajectories[1], topologies[2])
pA.plotProteinRMSD()
pA.plotLigandRMSD()
pA.plotByResRMSD()
pA.plotByResDih()
pA.correlatedMotions()
# Out:
# 100%|█████████████████████████████████████████| 125/125 [56:36<00:00, 27.17s/it]
